# %%
# %matplotlib inline

import gym
import itertools
import matplotlib
import numpy as np
import sys
import sklearn.pipeline
import sklearn.preprocessing

if "../" not in sys.path:
  sys.path.append("../") 

from lib import plotting
from lib.tile_coding import IHT, tiles
from sklearn.linear_model import SGDRegressor
from sklearn.kernel_approximation import RBFSampler
from matplotlib import pyplot as plt
matplotlib.style.use('ggplot')

# %%
env = gym.make("MountainCar-v0")
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
class Estimator():
    """
    Value Function approximator. 
    """
    
    def __init__(self, alpha, num_tilings=8, max_size=4096):
        self.max_size = max_size
        self.num_tilings = num_tilings

        # divide step size equally to each tiling
        self.alpha = alpha / num_tilings

        self.iht = IHT(max_size)

        # weight for each tile
        self.weights = np.zeros(max_size)

        # position and velocity needs scaling to satisfy the tile software
        self.position_scale = self.num_tilings / (env.observation_space.high[0] - env.observation_space.low[0])
        self.velocity_scale = self.num_tilings / (env.observation_space.high[1] - env.observation_space.low[1])
       
    def featurize_state_action(self, state, action):
        """
        Returns the featurized representation for a state.
        """
        featurized = tiles(self.iht, self.num_tilings, [self.position_scale * state[0], self.velocity_scale * state[1]], [action])
        return featurized
    
    def predict(self, s, a=None):
        """
        Makes value function predictions.
        
        Args:
            s: state to make a prediction for
            a: (Optional) action to make a prediction for
            
        Returns
            If an action a is given this returns a single number as the prediction.
            If no action is given this returns a vector or predictions for all actions
            in the environment where pred[i] is the prediction for action i.
            
        """
    
        if a is None:
            features = [self.featurize_state_action(s, i) for i in range(env.action_space.n)]
        else:
            features = [self.featurize_state_action(s, a)]
            
        return [np.sum(self.weights[f]) for f in features]
        
    
    def update(self, s, a, target):
        """
        Updates the estimator parameters for a given state and action towards
        the target y.
        """
        features = self.featurize_state_action(s, a)
        estimation = np.sum(self.weights[features])
        delta = self.alpha * (target - estimation)
        for f in features:
            self.weights[f] += delta

# %%
def make_epsilon_greedy_policy(estimator, epsilon, nA):
    """
    Creates an epsilon-greedy policy based on a given Q-function approximator and epsilon.
    
    Args:
        estimator: An estimator that returns q values for a given state
        epsilon: The probability to select a random action . float between 0 and 1.
        nA: Number of actions in the environment.
    
    Returns:
        A function that takes the observation as an argument and returns
        the probabilities for each action in the form of a numpy array of length nA.
    
    """
    def policy_fn(observation):
        A = np.ones(nA, dtype=float) * epsilon / nA
        q_values = estimator.predict(observation)
        best_action = np.argmax(q_values)
        A[best_action] += (1.0 - epsilon)
        return A
    return policy_fn

# %%
def q_learning(env, estimator, num_episodes, discount_factor=1.0, epsilon=0.1, epsilon_decay=1.0, n=1):
    """
    Q-Learning algorithm for fff-policy TD control using Function Approximation.
    Finds the optimal greedy policy while following an epsilon-greedy policy.
    
    Args:
        env: OpenAI environment.
        estimator: Action-Value function estimator
        num_episodes: Number of episodes to run for.
        discount_factor: Gamma discount factor.
        epsilon: Chance the sample a random action. Float betwen 0 and 1.
        epsilon_decay: Each episode, epsilon is decayed by this factor
    
    Returns:
        An EpisodeStats object with two numpy arrays for episode_lengths and episode_rewards.
    """

    # Keeps track of useful statistics
    stats = plotting.EpisodeStats(
        episode_lengths=np.zeros(num_episodes),
        episode_rewards=np.zeros(num_episodes))    
    
    for i_episode in range(num_episodes):
        
        
        # The policy we're following
        policy = make_epsilon_greedy_policy(
            estimator, epsilon * epsilon_decay**i_episode, env.action_space.n)
        
        # Print out which episode we're on, useful for debugging.
        # Also print reward for last episode
        last_reward = stats.episode_rewards[i_episode - 1]
        sys.stdout.flush()
        
        # Reset the environment and pick the first action
        state = env.reset()
        start_action_probs = policy(state)
        start_action = np.random.choice(np.arange(len(start_action_probs)), p=start_action_probs)
        
        
        # Only used for SARSA, not Q-Learning
        next_action = None
        
        # One step in the environment
        T = float('inf')
        for t in itertools.count():
            if t < T:           
                # Choose an action to take
                # If we're using SARSA we already decided in the previous step
                if next_action is None:
                    action_probs = policy(state)
                    action = np.random.choice(np.arange(len(action_probs)), p=action_probs)

                    # set up trackers
                    states = [state]
                    actions = [action]
                    rewards = [0.0]
                    term = [False]
                else:
                    action = next_action
            
                # Take a step
                next_state, reward, done, _ = env.step(action)
                states.append(next_state)
                rewards.append(reward)
                term.append(done)
                
                if done:
                    T = t + 1
                    
                else:
                    next_action_probs = policy(next_state)
                    next_action = np.random.choice(np.arange(len(next_action_probs)), p=next_action_probs)

                    actions.append(next_action)

                    # Update statistics
                    stats.episode_rewards[i_episode] += reward
                    stats.episode_lengths[i_episode] = t
                                           
            update_time = t + 1 - n
            if update_time >= 0:
                returns = 0
                # accumulate rewards
                for t_ in range(update_time + 1, min(T, update_time + n) + 1):
                    returns += rewards[t_]
                # add estimated state action value to the return
                if update_time + n < T:
                    q_values_next = estimator.predict(states[update_time + n])
                    returns += q_values_next[actions[update_time + n]]
                #if not term[update_time]:
                estimator.update(states[update_time], actions[update_time], returns)
            if update_time == T - 1:
                break
            
            state = next_state
            
            print("\rStep {} @ Episode {}/{} ({})".format(t, i_episode + 1, num_episodes, last_reward), end="")
    
    return stats

# %%
estimator = Estimator(alpha=0.5)

# %%
# Note: For the Mountain Car we don't actually need an epsilon > 0.0
# because our initial estimate for all states is too "optimistic" which leads
# to the exploration of all states.
stats = q_learning(env, estimator, 500, epsilon=0, n=1)
# Out:
# Step 40 @ Episode 104/500 (-123.0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-4ca064ff69b9> in <module>()
#       2 # because our initial estimate for all states is too "optimistic" which leads
#       3 # to the exploration of all states.
# ----> 4 stats = q_learning(env, estimator, 500, epsilon=0, n=1)
#
# <ipython-input-5-d2cbecccdae1> in q_learning(env, estimator, num_episodes, discount_factor, epsilon, epsilon_decay, n)
#      87                 # add estimated state action value to the return
#      88                 if update_time + n < T:
# ---> 89                     q_values_next = estimator.predict(states[update_time + n])
#      90                     returns += q_values_next[actions[update_time + n]]
#      91                 #if not term[update_time]:
#
# <ipython-input-3-ea3f6f1d454a> in predict(self, s, a)
#      43
#      44         if a is None:
# ---> 45             features = [self.featurize_state_action(s, i) for i in range(env.action_space.n)]
#      46         else:
#      47             features = [self.featurize_state_action(s, a)]
#
# <ipython-input-3-ea3f6f1d454a> in <listcomp>(.0)
#      43
#      44         if a is None:
# ---> 45             features = [self.featurize_state_action(s, i) for i in range(env.action_space.n)]
#      46         else:
#      47             features = [self.featurize_state_action(s, a)]
#
# <ipython-input-3-ea3f6f1d454a> in featurize_state_action(self, state, action)
#      24         Returns the featurized representation for a state.
#      25         """
# ---> 26         featurized = tiles(self.iht, self.num_tilings, [self.position_scale * state[0], self.velocity_scale * state[1]], [action])
#      27         return featurized
#      28
#
# ~/Documents/RL/lib/tile_coding.py in tiles(ihtORsize, numtilings, floats, ints, readonly)
#      80         b = tiling
#      81         for q in qfloats:
# ---> 82             coords.append( (q + b) // numtilings )
#      83             b += tilingX2
#      84         coords.extend(ints)
#
# KeyboardInterrupt:

# %%
plotting.plot_cost_to_go_mountain_car(env, estimator)
plotting.plot_episode_stats(stats, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %%
def figure10_4():
    alphas = np.arange(0.25, 1.75, 0.25)
    nSteps = np.power(2, np.arange(0, 5))
    episodes = 100
    runs = 10

    truncateStep = 300
    steps = np.zeros((len(nSteps), len(alphas)))
    for run in range(0, runs):
        for nStepIndex, nStep in zip(range(0, len(nSteps)), nSteps):
            for alphaIndex, alpha in zip(range(0, len(alphas)), alphas):
                if (nStep == 8 and alpha > 1) or \
                        (nStep == 16 and alpha > 0.75):
                    # In these cases it won't converge, so ignore them
                    steps[nStepIndex, alphaIndex] += truncateStep * episodes
                    continue
                estimator = Estimator(alpha=alpha)
                for episode in range(0, episodes):
                    print('run:', run, 'steps:', nStep, 'alpha:', alpha, 'episode:', episode)
                    stats = q_learning(env, estimator, 1, epsilon=0, n=nStep)
                    step = stats.episode_lengths[-1]
                    steps[nStepIndex, alphaIndex] += step
    # average over independent runs and episodes
    steps /= runs * episodes
    # truncate high values for better display
    steps[steps > truncateStep] = truncateStep

    plt.figure()
    for i in range(0, len(nSteps)):
        plt.plot(alphas, steps[i, :], label='n = '+str(nSteps[i]))
    plt.xlabel('alpha * number of tilings(8)')
    plt.ylabel('Steps per episode')
    plt.legend()

# %%
figure10_4()
# Out:
# run: 0 steps: 1 alpha: 0.25 episode: 0
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 1
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 2
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 3
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 4
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 5
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 6
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 7
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 8
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 9
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 10
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 11
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 12
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 13
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 14
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 15
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 16
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 17
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 18
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 19
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 20
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 21
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 22
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 23
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 24
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 25
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 26
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 27
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 28
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 29
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 30
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 31
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 32
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 33
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 34
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 35
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 36
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 37
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 38
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 39
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 40
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 41
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 42
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 43
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 44
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 45
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 46
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 47
# Step 195 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 48
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 49
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 50
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 51
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 52
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 53
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 54
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 55
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 56
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 57
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 58
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 59
# Step 181 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 60
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 61
# Step 162 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 62
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 63
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 64
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 65
# Step 157 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 66
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 67
# Step 163 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 68
# Step 158 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 69
# Step 169 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 70
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 71
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 72
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 73
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 74
# Step 161 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 75
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 76
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 77
# Step 191 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 78
# Step 194 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 79
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 80
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 81
# Step 158 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 82
# Step 185 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 83
# Step 165 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 84
# Step 155 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 85
# Step 188 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 86
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 87
# Step 154 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 88
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 89
# Step 155 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 90
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 91
# Step 160 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 92
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 93
# Step 154 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 94
# Step 146 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 95
# Step 134 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 96
# Step 194 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 97
# Step 164 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 98
# Step 161 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.25 episode: 99
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 0
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 1
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 2
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 3
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 4
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 5
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 6
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 7
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 8
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 9
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 10
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 11
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 12
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 13
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 14
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 15
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 16
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 17
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 18
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 19
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 20
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 21
# Step 192 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 22
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 23
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 24
# Step 173 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 25
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 26
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 27
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 28
# Step 195 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 29
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 30
# Step 181 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 31
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 32
# Step 188 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 33
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 34
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 35
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 36
# Step 181 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 37
# Step 189 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 38
# Step 168 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 39
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode: 40
# Step 198 @ Episode 1/1 (0.0)run: 0 steps: 1 alpha: 0.5 episode:
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 14
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 15
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 16
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 17
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 18
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 19
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 20
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 21
# Step 176 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 22
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 23
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 24
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 25
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 26
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 27
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 28
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 29
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 30
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 31
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 32
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 33
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 34
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 35
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 36
# Step 156 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 37
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 38
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 39
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 40
# Step 192 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 41
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 42
# Step 174 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 43
# Step 201 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 44
# Step 176 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 45
# Step 167 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 46
# Step 145 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 47
# Step 146 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 48
# Step 142 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 49
# Step 176 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 50
# Step 155 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 51
# Step 149 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 52
# Step 153 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 53
# Step 170 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 54
# Step 128 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 55
# Step 188 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 56
# Step 159 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 57
# Step 190 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 58
# Step 178 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 59
# Step 156 @ Episode 1/1 (0.0)run: 9 steps: 4 alpha: 0.25 episode: 60
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 32
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 33
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 34
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 35
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 36
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 37
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 38
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 39
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 40
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 41
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 42
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 43
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 44
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 45
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 46
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 47
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 48
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 49
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 50
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 51
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 52
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 53
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 54
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 55
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 56
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 57
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 58
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 59
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 60
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 61
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 62
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 63
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 64
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 65
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 66
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 67
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 68
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 69
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 70
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 71
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 72
# Step 182 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 73
# Step 174 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 74
# Step 189 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 75
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 76
# Step 184 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 77
# Step 189 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 78
# Step 174 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 79
# Step 210 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 80
# Step 176 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 81
# Step 171 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 82
# Step 166 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 83
# Step 175 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 84
# Step 182 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 85
# Step 182 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 86
# Step 181 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 87
# Step 202 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 88
# Step 181 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 89
# Step 188 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 90
# Step 176 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 91
# Step 197 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 92
# Step 181 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 93
# Step 198 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 94
# Step 206 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 95
# Step 196 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 96
# Step 202 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 97
# Step 202 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 98
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.5 episode: 99
# Step 203 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 0
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 1
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 2
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 3
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 4
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 5
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 6
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 7
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 8
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 9
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 10
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 11
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 12
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 13
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 14
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 15
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 16
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 17
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 18
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 19
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 20
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 21
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 22
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 23
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 24
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 25
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 26
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 27
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 28
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 29
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 30
# Step 203 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 31
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 32
# Step 194 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 33
# Step 194 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 34
# Step 197 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 35
# Step 200 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 36
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 37
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 38
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 39
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 40
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 41
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 42
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 43
# Step 177 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 44
# Step 196 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 45
# Step 181 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 46
# Step 203 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 47
# Step 208 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 48
# Step 203 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 49
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 50
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 51
# Step 203 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 52
# Step 195 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 53
# Step 176 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 54
# Step 175 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 55
# Step 179 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 56
# Step 164 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 57
# Step 144 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 58
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 59
# Step 197 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 60
# Step 129 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 61
# Step 137 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 62
# Step 134 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 63
# Step 99 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 64
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 65
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 66
# Step 160 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 67
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 68
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 69
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 70
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 71
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 72
# Step 192 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 73
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 74
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 75
# Step 142 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 76
# Step 190 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 77
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 78
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 79
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 80
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 81
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 82
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 83
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 84
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 85
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 86
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 87
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 88
# Step 142 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 89
# Step 166 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 90
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 91
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 92
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 93
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 94
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 95
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 96
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 97
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 98
# Step 213 @ Episode 1/1 (0.0)run: 9 steps: 16 alpha: 0.75 episode: 99
# Step 213 @ Episode 1/1 (0.0)

# %% [markdown]
# ## Plot learned policy

# %%
import time
env = gym.make("MountainCar-v0")
epsilon = 0
# The policy we're following
policy = make_epsilon_greedy_policy(
        estimator, epsilon, env.action_space.n)
#for i_episide in range(20):
state = env.reset()
for t in itertools.count():
    #env.render()
    time.sleep(0.01)
    action_probs = policy(state)
    action = np.random.choice(np.arange(len(action_probs)), p=action_probs)
    state, _, done, _ = env.step(action)
    env.render()
    if done:
        break
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
